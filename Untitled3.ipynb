# %% [markdown]
# <a href="https://colab.research.google.com/github/abasalashore30-maker/Meta-spacetime-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install emcee corner

# %%
# !git clone https://github.com/abasalashore30-maker/Meta-spacetime.git
# Out:
# Cloning into 'Meta-spacetime'...
# fatal: could not read Username for 'https://github.com': No such device or address
